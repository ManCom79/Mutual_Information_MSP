# %% [markdown]
# <a href="https://colab.research.google.com/github/ManCom79/Mutual_Information_MSP/blob/GCE-LogCalculator/Communities_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
##Map GoogleDrive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#Reading the maximum value of the datafield
#coins_mi_scores.csv contains MI matrix
import numpy
import pandas as pd
dfx=pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/coins_mi_scores.csv')
dfx.pop('Unnamed: 0')
dfx.head()
max = dfx.max(numeric_only=True).max()
print(max)

#Subtract every cell value from max
values = numpy.array(dfx)
array = abs((values - max))

#New dataframe that has the final array for the minimum spanning tree
#Export the dataframe to file
dfy = pd.DataFrame(data=array)
dfy.to_csv("/content/gdrive/MyDrive/Colab Notebooks/coins_MSI_entries_test.csv")
dfy.head()
# Out:
# 6.83075404281854
#         0         1         2         3         4         5         6    \
# 0  4.308287  5.799609  5.966366  6.128404  6.768343  6.409690  6.095805
# 1  5.808498  2.309613  5.632895  6.149970  6.818733  6.527540  5.466940
# 2  5.969921  5.630661  0.358440  6.212876  6.772805  6.428287  5.492926
# 3  6.118379  6.139203  6.215538  3.888419  6.787672  6.559072  6.281735
# 4  6.764060  6.801486  6.774270  6.751485  6.694187  6.760443  6.796095
#
#         7         8         9    ...       676       677       678       679  \
# 0  6.082681  5.922237  6.102989  ...  6.251908  6.015287  5.927720  6.251665
# 1  5.656027  5.624833  5.190723  ...  5.711731  5.788633  6.098437  5.470383
# 2  5.914285  5.635993  5.706154  ...  5.800489  5.850073  6.153259  5.679419
# 3  6.032201  6.059200  6.370399  ...  6.403615  6.022127  6.197469  6.284876
# 4  6.830754  6.752570  6.786566  ...  6.805992  6.762985  6.790900  6.805643
#
# ...

# %%
import pandas as pd
from scipy.sparse import csr_matrix
from scipy.sparse.csgraph import minimum_spanning_tree
import networkx as nx
import matplotlib.pyplot as plt
import matplotlib.cm as cm
# %matplotlib inline
from community import community_louvain

X=pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/coins_MSI_entries_test_01.csv')
X.pop('Unnamed: 0')
X.head()

####Generate values for the minimum spanning tree of the datafield
Tcsr = minimum_spanning_tree(X)
Tcsr.toarray().astype(float)

####Plot the minimum spanning tree
print(Tcsr)
MST = nx.Graph(Tcsr.toarray().astype(float))

####VISUALIZATION PART
def community_detection(G):
  return community_louvain.best_partition(G) 

partition = community_detection(MST) #povikuvass funkcija

#### visualization
mapping = {0: "1X21X2 COIN",	1: "2GIVE2GIVE",	2: "4242-coin",	3: "ABBCABBC Coin",	4: "ACAAcala Token",	5: "ACMActinium",	6: "ACOINAcoin",	7: "ACTAchain",	8: "ADACardano",	9: "ADCAudioCoin",	10: "ADKAidos Kuneen",	11: "ADMADAMANT Messenger",	12: "ADSAdshares",	13: "ADZAdzcoin",	14: "AEAeternity",	15: "AEONAeon",	16: "AG8AtromG8",	17: "AHTAhaToken",	18: "AIONAion",	19: "AIOZAIOZ Network",	20: "AKAAkroma",	21: "AKTAkash Network",	22: "ALGOAlgorand",	23: "ALLAlliance Fan Token",	24: "AMBAmbrosus",	25: "AMSAmsterdamCoin",	26: "ANCAnoncoin",	27: "ANONANON",	28: "APLApollo Currency",	29: "ARArweave",	30: "ARBARbit",	31: "ARCOAquariusCoin",	32: "ARDRArdor",	33: "AREPAArepacoin",	34: "ARIONArion",	35: "ARKArk",	36: "AROArionum",	37: "ARQArqma",	38: "ARRRPirate Chain",	39: "ASAFEAllSafe",	40: "ASKPermission Coin",	41: "ATBATBCoin",	42: "ATOMCosmos",	43: "AUXAuxilium",	44: "AVAXAvalanche",	45: "AXEAxe",	46: "AYAAryacoin",	47: "BANBanano",	48: "BBKBitblocks",	49: "BBPBiblePay",	50: "BBRBoolberry",	51: "BBSBBSCoin",	52: "BCABitcoin Atom",	53: "BCBitcoin Confidential",	54: "BCDBitcoin Diamond",	55: "BCHBitcoin Cash",	56: "BCNBytecoin",	57: "BCZBitcoin CZ",	58: "BEAMBeam",	59: "BECNBeacon",	60: "BEETBeetlecoin",	61: "BERNBERNcash",	62: "BGLBitgesell",	63: "BHDBitcoinHD",	64: "BHPBHPCoin",	65: "BIPMinter Network",	66: "BIRBirake",	67: "BISBismuth",	68: "BITBBean Cash",	69: "BITCBitCash",	70: "BITGBitcoin Green",	71: "BITSBitstar",	72: "BLASTBLAST",	73: "BLKBlackCoin",	74: "BLKCBlackHat",	75: "BLOCBLOC.MONEY",	76: "BLOCKBlocknet",	77: "BLTGBlock-Logic",	78: "BLUBlueCoin",	79: "BNBBNB",	80: "BOBABoba Network",	81: "BOLIBolivarcoin",	82: "BPCBackPacker Coin",	83: "BPSBitcoinPoS",	84: "BSCBowsCoin",	85: "BSDBitSend",	86: "BSTYGlobalBoost-Y",	87: "BSVBitcoin SV",	88: "BTABata",	89: "BTADBitcoin Adult",	90: "BTC2Bitcoin 2",	91: "BTCBitcoin",	92: "BTCNBitcoiNote",	93: "BTCPBitcoin Private",	94: "BTCTBitcoin Token",	95: "BTCZBitcoinZ",	96: "BTDXBitcloud",	97: "BTGBitcoin Gold",	98: "BTMBytom",	99: "BTOBottos",	100: "BTSBitShares",	101: "BTWBitWhite",	102: "BTXBitCore",	103: "BUZZBUZZCoin",	104: "BXCBitcoin Classic",	105: "BZEBZEdge",	106: "BZXBitcoin Zero",	107: "C2Coin2.1",	108: "CANNCannabisCoin",	109: "CARBONCarboncoin",	110: "CARECarebit",	111: "CCXConceal",	112: "CCXXCounos X",	113: "CELOCelo",	114: "CENNZCENNZnet",	115: "CETCoinEx Token",	116: "CFCalifornium",	117: "CFGCentrifuge",	118: "CFLCryptoFlow",	119: "CHATChatCoin",	120: "CHEESECheesecoin",	121: "CHESSChessCoin",	122: "CHIXaya",	123: "CHXWeOwn",	124: "CIVCivitas",	125: "CJCryptojacks",	126: "CKBNervos Network",	127: "CLCCaluraCoin",	128: "CLHClearDAO",	129: "CLOAKCloakCoin",	130: "CLOCallisto Network",	131: "CMMCommercium",	132: "CMTCyberMiles",	133: "CNTCenturion",	134: "CNTRCentaur",	135: "COALBitCoal",	136: "COLXColossusXT",	137: "COTICOTI",	138: "CPUCPUchain",	139: "CREDITCREDIT",	140: "CREVACrevaCoin",	141: "CRMCream",	142: "CROATCROAT",	143: "CRONCryptocean",	144: "CRPCrypton",	145: "CRWCrown",	146: "CSCredits",	147: "CSPNCrypto Sports",	148: "CSPRCasper",	149: "CSTLCastle",	150: "CTKCertiK",	151: "CTLCitadel",	152: "CTXCCortex",	153: "CURECurecoin",	154: "CUTCUTcoin",	155: "DAGConstellation",	156: "DAPSDAPS Coin",	157: "DASHDash",	158: "DCNTRDecentrahub Coin",	159: "DCRDecred",	160: "DDKDDKoin",	161: "DDenarius",	162: "DEALiDealCash",	163: "DEMDeutsche eMark",	164: "DERODero",	165: "DESODecentralized Social",	166: "DFIDeFiChain",	167: "DFTDraftCoin",	168: "DGBDigiByte",	169: "DGCDigitalcoin",	170: "DIMEDimecoin",	171: "DIVIDivi",	172: "DLCDollarcoin",	173: "DMBDigital Money Bits",	174: "DMCHDarma Cash",	175: "DMDDiamond",	176: "DNAMetaverse Dualchain Network Architecture",	177: "DOGECDogeCash",	178: "DOGEDogecoin",	179: "DONUDonu",	180: "DOPEDopeCoin",	181: "DOTPolkadot",	182: "DRMDreamcoin",	183: "DSRDesire",	184: "DTCDatacoin",	185: "DTEPDECOIN",	186: "DYNDynamic",	187: "EBSTeBoost",	188: "EDCEDC Blockchain",	189: "EDGEdgeware",	190: "EDRCEDRCoin",	191: "EFLe-Gulden",	192: "EGEMEtherGem",	193: "EGGNestEGG Coin",	194: "EGLDElrond",	195: "ELAElastos",	196: "EMC2Einsteinium",	197: "EMCEmercoin",	198: "ENQEnecuum",	199: "ENRGEnergycoin",	200: "ENTEternity",	201: "EOSCEOS Force",	202: "EOSEOS",	203: "EPICEpic Cash",	204: "ERGErgo",	205: "ERKEureka Coin",	206: "ESBCESBC",	207: "ETCEthereum Classic",	208: "ETHEthereum",	209: "ETHOEtho Protocol",	210: "ETIEtherInc",	211: "ETNElectroneum",	212: "ETPMetaverse ETP",	213: "ETZEther Zero",	214: "EUNOEUNO",	215: "EVEREverscale",	216: "EVILEvil Coin",	217: "EVTEveriToken",	218: "EWTEnergy Web Token",	219: "EXCLExclusiveCoin",	220: "EXPExpanse",	221: "FAIRFairCoin",	222: "FBNFivebalance",	223: "FCTFactom",	224: "FGCFantasyGold",	225: "FILFilecoin",	226: "FIOFIO Protocol",	227: "FIROFiro",	228: "FJCFujiCoin",	229: "FLOWFlow",	230: "FLUXFlux",	231: "FOFIBOS",	232: "FRCFreicoin",	233: "FREEDFreedomcoin",	234: "FRSTFirstCoin",	235: "FSNFusion",	236: "FTCFeathercoin",	237: "FTMFantom",	238: "FUZZFuzzBalls",	239: "FYDFYDcoin",	240: "GBGoldBlocks",	241: "GBXGoByte",	242: "GBYTEObyte",	243: "GCCGlobal Cryptocurrency",	244: "GCCGuccioneCoin",	245: "GCNGCN Coin",	246: "GCRGlobal Currency Reserve",	247: "GHOSTGHOSTPRISM",	248: "GHOSTGhost",	249: "GIOGraviocoin",	250: "GLCGoldcoin",	251: "GLEECGleec",	252: "GLMRMoonbeam",	253: "GLSGolos Blockchain",	254: "GLTGlobalToken",	255: "GOGoChain",	256: "GOSSGossip Coin",	257: "GRCGridcoin",	258: "GRFTGraft",	259: "GRIMMGrimm",	260: "GRINGrin",	261: "GRLCGarlicoin",	262: "GRSGroestlcoin",	263: "GSRGeyserCoin",	264: "GTMGentarium",	265: "GXCGXChain",	266: "GXXGravityCoin",	267: "HBARHedera",	268: "HCHyperCash",	269: "HEATHEAT",	270: "HELPGoHelpFund",	271: "HIVEHive",	272: "HLIXHelix",	273: "HNSHandshake",	274: "HNTHelium",	275: "HOPRHOPR",	276: "HPBHigh Performance Blockchain",	277: "HTDFOrient Walt",	278: "HTMLHTMLCOIN",	279: "HTRHathor",	280: "HTZHertz Network",	281: "HUSHHush",	282: "HYCHYCON",	283: "HYDRAHydra",	284: "HYNHyperion",	285: "ICIgnition",	286: "ICOBICOBID",	287: "ICPInternet Computer",	288: "ICXICON",	289: "IDNAIdena",	290: "IFCInfinitecoin",	291: "ILCILCOIN",	292: "IMGImageCoin",	293: "IMSIndependent Money System",	294: "INNInnova",	295: "INSNInsaneCoin",	296: "INSTARInsights Network",	297: "INTINT",	298: "IOCI/O Coin",	299: "IONION",	300: "IOSTIOST",	301: "IOTXIoTeX",	302: "IQIQ.cash",	303: "IRDIridium",	304: "IRISIRISnet",	305: "IXCIxcoin",	306: "JUPJupiter",	307: "KAIKardiaChain",	308: "KDAKadena",	309: "KEMAKemacoin",	310: "KEXKira Network",	311: "KFXKnoxFS (New)",	312: "KINKin",	313: "KLAYKlaytn",	314: "KMDKomodo",	315: "KOBOKobocoin",	316: "KRBKarbo",	317: "KRTTerraKRW",	318: "KSMKusama",	319: "KTSKlimatas",	320: "KURTKurrent",	321: "LANALanaCoin",	322: "LATPlatON",	323: "LBCLBRY Credits",	324: "LBTCLightning Bitcoin",	325: "LCCLitecoin Cash",	326: "LCPLitecoin Plus",	327: "LHTLHT",	328: "LNLINK",	329: "LOBSLobstex",	330: "LOGWoodcoin",	331: "LSKLisk",	332: "LTCLitecoin",	333: "LTCRLitecred",	334: "LTHNLethean",	335: "LTOLTO Network",	336: "LUNALuna Coin",	337: "LUNATerra",	338: "LUXLUXCoin",	339: "LYRAScrypta",	340: "MANMatrix AI Network",	341: "MANNAManna",	342: "MARMchain",	343: "MAROMaro",	344: "MARTKMartkist",	345: "MASKNFTX Hashmasks Index",	346: "MASSMassnet",	347: "MATICPolygon",	348: "MAXMaxcoin",	349: "MAYTheresa May Coin",	350: "MBCMicroBitcoin",	351: "MCCMultiCoinCasino",	352: "MCMMochimo",	353: "MCPCMobile Crypto Pay Coin",	354: "MECMegacoin",	355: "MEDICMedicCoin",	356: "MEDMediBloc",	357: "MEMEMemetic / PepeCoin",	358: "METAMetadium",	359: "MHC#MetaHash",	360: "MIBMIB Coin",	361: "MINAMina",	362: "MINTMEMintMe.com Coin",	363: "MIOTAIOTA",	364: "MIRMIR COIN",	365: "MLMMktCoin",	366: "MNTPGoldMint",	367: "MOBMobileCoin",	368: "MODICModern Investment Coin",	369: "MOJOMojoCoin",	370: "MONAMonaCoin",	371: "MONKMONK",	372: "MOTAMotaCoin",	373: "MOTOMotocoin",	374: "MRXMetrix Coin",	375: "MSRMasari",	376: "MSTMustangCoin",	377: "MTRGMeter Governance",	378: "MTVMultiVAC",	379: "MUEMonetaryUnit",	380: "MWCMimbleWimbleCoin",	381: "MXTMarteXcoin",	382: "N8VNativeCoin",	383: "NASNebulas",	384: "NAVINatus Vincere Fan Token",	385: "NAVNavcoin",	386: "NBXNetbox Coin",	387: "NEARNEAR Protocol",	388: "NEBLNeblio",	389: "NEONeo",	390: "NETKONetko",	391: "NEVANevaCoin",	392: "NEWSPUBLISH",	393: "NEXTNEXT",	394: "NIMNimiq",	395: "NIXNIX",	396: "NKNNKN",	397: "NLGGulden",	398: "NMCNamecoin",	399: "NORNoir",	400: "NOTEDNotes",	401: "NRGEnergi",	402: "NSDNasdacoin",	403: "NTRNNeutron",	404: "NTRNetrum",	405: "NUKONekonium",	406: "NULSNULS",	407: "NVCNovacoin",	408: "NVTNerveNetwork",	409: "NXSNexus",	410: "NXTNxt",	411: "NYCNewYorkCoin",	412: "NYENewYork Exchange",	413: "NYEXNyerium",	414: "NYZONyzo",	415: "NZLZealium",	416: "OKOKCash",	417: "OMNIOmni",	418: "ONEHarmony",	419: "ONIONDeepOnion",	420: "ONTOntology",	421: "ONXOnix",	422: "OPALOpal",	423: "ORBOrbitcoin",	424: "OSMOOsmosis",	425: "OTOOTOCASH",	426: "OWCODUWA",	427: "OXENOxen",	428: "PACPAC Protocol",	429: "PAIProject Pai",	430: "PAKPakcoin",	431: "PARTParticl",	432: "PASCPascal",	433: "PCXChainX",	434: "PEGPegNet",	435: "PEPSPEPS Coin",	436: "PEXPosEx",	437: "PGNPigeoncoin",	438: "PGOPengolinCoin",	439: "PHAPhala Network",	440: "PHRPhore",	441: "PHTLightstreams",	442: "PINKPinkcoin",	443: "PINPublic Index Network",	444: "PIPlian",	445: "PIRATEPirateCash",	446: "PIVXPIVX",	447: "PKBParkByte",	448: "PLCPLATINCOIN",	449: "PLURAPluraCoin",	450: "PNXPhantomx",	451: "PNYPeony",	452: "POAPOA Network",	453: "POLISPolis",	454: "POSTPostCoin",	455: "POSWPoSW Coin",	456: "POTPotCoin",	457: "PPCPeercoin",	458: "PRCYPRCY Coin",	459: "PRXProxyNode",	460: "PTDPeseta Digital",	461: "PUTPutinCoin",	462: "PWRPWR Coin",	463: "PXCPhoenixcoin",	464: "PXIPrime-XI",	465: "PYRKPyrk",	466: "PZMPRIZM",	467: "QBCQuebecoin",	468: "QRKQuark",	469: "QRLQuantum Resistant Ledger",	470: "QTUMQtum",	471: "QUANQuantis Network",	472: "QWCQwertycoin",	473: "RADRadicle",	474: "RBIESRubies",	475: "RBTCRSK Smart Bitcoin",	476: "RBTRimbit",	477: "RDDReddCoin",	478: "REECRenewable Electronic Energy Coin",	479: "REEFReef",	480: "REVRChain",	481: "RFUELRioDeFi",	482: "RINGXRING X PLATFORM",	483: "RISERise",	484: "RITORitocoin",	485: "ROCOROIyal Coin",	486: "RPDRapids",	487: "RUPRupee",	488: "RVCRavencoin Classic",	489: "RVNRavencoin",	490: "RYORyo Currency",	491: "SAFESafe",	492: "SAFESafeCoin",	493: "SAPPSapphire",	494: "SBDSteem Dollars",	495: "SCCStakeCubeCoin",	496: "SCHOScholarship Coin",	497: "SCPScPrime",	498: "SCRIVSCRIV NETWORK",	499: "SCRScorum Coins",	500: "SCRTSecret",	501: "SCSiacoin",	502: "SEMSemux",	503: "SEROSuper Zero Protocol",	504: "SFDSAFE DEAL",	505: "SFTSafex Token",	506: "SFXSafex Cash",	507: "SHBSkyHub Coin",	508: "SHFTShyft Network",	509: "SHMNStrongHands Masternode",	510: "SHNDStrongHands",	511: "SHOShowcase",	512: "SIBSIBCoin",	513: "SIGNASignum",	514: "SINSINOVATE",	515: "SINSSafeInsure",	516: "SKYSkycoin",	517: "SMARTSmartCash",	518: "SMCSmartCoin (SMC)",	519: "SMLYSmileyCoin",	520: "SNDSnodeCoin",	521: "SNRGSynergy",	522: "SOLSolana",	523: "SONGSongCoin",	524: "SONOSonoCoin",	525: "SPDStipend",	526: "SPHTXSophiaTX",	527: "SPKSparksPay",	528: "SPRSpreadCoin",	529: "SRMSerum",	530: "STARTStartcoin",	531: "STEEMSteem",	532: "STEEPSteepCoin",	533: "STRAXStratis",	534: "STREAMStreamit Coin",	535: "STXStacks",	536: "SUMOSumokoin",	537: "SUPERSuperCoin",	538: "SWIFTSwiftCash",	539: "SWINGSwing",	540: "SXPSXP",	541: "SYSSyscoin",	542: "TAGTagCoin",	543: "TAJTajCoin",	544: "TAULamden",	545: "TCCThe ChampCoin",	546: "TELOSTeloscoin",	547: "TENTTENT",	548: "TERATERA",	549: "TFUELTheta Fuel",	550: "THCHempCoin",	551: "THETATheta Network",	552: "TIPSFedoraCoin",	553: "TLOSTelos",	554: "TNCTNC Coin",	555: "TNTurtleNetwork",	556: "TOMOTomoChain",	557: "TONToncoin",	558: "TPAYTokenPay",	559: "TRCTerracoin",	560: "TRIASTrias Token (new)",	561: "TROLLTrollcoin",	562: "TRTLTurtleCoin",	563: "TRTTTrittium",	564: "TRUETrueChain",	565: "TRXTRON",	566: "TTNTitan Coin",	567: "TTThunderCore",	568: "TUBEBitTube",	569: "TUPTenUp",	570: "TXTransferCoin",	571: "TZCTrezarCoin",	572: "UBQUbiq",	573: "UBXUBIX.Network",	574: "UCAUCA Coin",	575: "UNIFYUnify",	576: "UNITUniversal Currency",	577: "UPXuPlexa",	578: "USDXUSDX [Lighthouse]",	579: "USNBTNuBits",	580: "USTTerraUSD",	581: "VALValidity",	582: "VAULTVAULT",	583: "VDLVidulum",	584: "VEILVeil",	585: "VETVeChain",	586: "VEXVexanium",	587: "VIAViacoin",	588: "VIDZPureVidz",	589: "VINVINchain",	590: "VIPSVipstar Coin",	591: "VITEVITE",	592: "VIVIDVivid Coin",	593: "VLSVeles",	594: "VLTVeltor",	595: "VLXVelas",	596: "VOTVoteCoin",	597: "VRCVeriCoin",	598: "VRSCVerusCoin",	599: "VSYSv.systems",	600: "VTCVertcoin",	601: "WAGEDigiwage",	602: "WANWanchain",	603: "WAVESWaves",	604: "WAXPWAX",	605: "WCCWinCash",	606: "WEBDWebDollar",	607: "WGRWagerr",	608: "WICCWaykiChain",	609: "WORLDWorld Token",	610: "WOWWownero",	611: "WTRXWrapped TRON",	612: "X42x42 Protocol",	613: "XASAsch",	614: "XBCBitcoin Plus",	615: "XBIBitcoin Incognito",	616: "XBTC21Bitcoin 21",	617: "XBYXTRABYTES",	618: "XCASHX-CASH",	619: "XCHChia",	620: "XCNCryptonite",	621: "XCOX-Coin",	622: "XCPCounterparty",	623: "XDCXDC Network",	624: "XDNDigitalNote",	625: "XECeCash",	626: "XEMNEM",	627: "XEPElectra Protocol",	628: "XFCFootballcoin (XFC)",	629: "XFLFlorin",	630: "XGMDefis",	631: "XGSGenesisX",	632: "XHIHiCoin",	633: "XHVHaven Protocol",	634: "XLAScala",	635: "XLMStellar",	636: "XLRSolaris",	637: "XLTNexalt",	638: "XMCMonero Classic",	639: "XMRMonero",	640: "XMVMoneroV",	641: "XMYMyriad",	642: "XNCXeniosCoin",	643: "XNONano",	644: "XNVNerva",	645: "XPCeXPerience Chain",	646: "XPDPetroDollar",	647: "XPMPrimecoin",	648: "XPRProton",	649: "XPXProximaX",	650: "XPYPayCoin",	651: "XRARatecoin",	652: "XRCxRhodium",	653: "XRPXRP",	654: "XSHSHIELD",	655: "XSNStakenet",	656: "XSTStealth",	657: "XTZTezos",	658: "XUEZXuez",	659: "XVGVerge",	660: "XWCWhiteCoin",	661: "XWPSwap",	662: "XYMSymbol",	663: "YBOYoung Boys Fan Token",	664: "YECYcash",	665: "YOCYocoin",	666: "YOYOWYOYOW",	667: "YTNYENTEN",	668: "ZANOZano",	669: "ZCLZClassic",	670: "ZCRZCore",	671: "ZEBIZebi Token",	672: "ZECZcash",	673: "ZENHorizen",	674: "ZENIZennies",	675: "ZERZero",	676: "ZETZetacoin",	677: "ZILZilliqa",	678: "ZNNZenon",	679: "ZNYBitzeny",	680: "ZNZZENZO",	681: "ZPTZeepin",	682: "ZUMZumCoin",	683: "ZYDZayedcoin",	684: "ZYNZynecoin",	685: "erowanSifChain"}
pos = nx.spring_layout(MST)
plt.figure(3,figsize=(50,50))
MST1 = nx.relabel_nodes(MST, mapping)
nx.draw_networkx_nodes(MST, pos, alpha=0.5, node_size=300, node_color=list(partition.values()))
nx.draw_networkx_edges(MST, pos, alpha=0.1)
nx.draw_networkx_labels(MST, pos, labels=mapping, alpha=1)
# Out:
#   (0, 162)	5.537288182
#   (1, 13)	5.017892903
#   (1, 25)	5.009973113
#   (1, 172)	4.881321634
#   (1, 299)	5.347509229
#   (1, 381)	5.377898353
#   (1, 543)	4.989912627
#   (4, 453)	6.711094446
#   (6, 91)	5.233346676
#   (7, 119)	5.415397877
#   (8, 97)	5.391388731
#   (8, 225)	5.412236262
#   (8, 288)	5.362001774
#   (8, 356)	5.468243115
#   (8, 565)	5.329442442
#   (8, 677)	5.426340325
#   (9, 228)	4.924339841
#   (13, 665)	5.519757637
#   (14, 132)	5.384436019
#   (14, 212)	5.436122114
#   (17, 511)	6.410144885
#   (18, 388)	5.370645105
#   (20, 36)	5.463819344
#   (21, 51)	6.737178142
#   (22, 137)	5.741794643
#   :	:
#   (660, 382)	5.60679966
#   (662, 23)	6.319626504
#   (663, 384)	6.217475395
#   (663, 458)	6.31775139
#   (664, 493)	5.990893532
#   (667, 480)	5.599244112
#   (668, 414)	6.052219795
#   (669, 145)	5.360019194
#   (672, 207)	5.259728408
#   (673, 208)	5.378213738
#   (674, 103)	5.212003738
#   (674, 256)	5.687068522
#   (674, 261)	5.491568812
# ...

# %%
import networkx as nx
import graphpca
g = graphpca.reduce_graph(MST, 2)
plt.figure(3,figsize=(20,20))
graphpca.plot_2d(g)
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py'>
